# %%
import pandas as pd
import numpy as np
from glob import glob

# %%
glob("*.txt")
# Out:
# ['words.txt', 'CollinsScrabbleWords_2015.txt']

# %%
pd.read_csv('CollinsScrabbleWords_2015.txt')
# Out:
#                    AA
# 0                 AAH
# 1               AAHED
# 2              AAHING
# 3                AAHS
# 4                 AAL
# 5               AALII
# 6              AALIIS
# 7                AALS
# 8            AARDVARK
# 9           AARDVARKS
# 10           AARDWOLF
# 11         AARDWOLVES
# 12              AARGH
# 13             AARRGH
# 14            AARRGHH
# 15              AARTI
# 16             AARTIS
# 17                AAS
# 18           AASVOGEL
# 19          AASVOGELS
# 20                 AB
# 21                ABA
# 22               ABAC
# 23              ABACA
# 24             ABACAS
# 25              ABACI
# 26              ABACK
# 27              ABACS
# 28         ABACTERIAL
# 29          ABACTINAL
# ...               ...
# 276612     ZYMOLOGIST
# 276613    ZYMOLOGISTS
# 276614       ZYMOLOGY
# 276615      ZYMOLYSES
# 276616      ZYMOLYSIS
# 276617      ZYMOLYTIC
# 276618         ZYMOME
# 276619        ZYMOMES
# 276620      ZYMOMETER
# ...
